# %%
import pandas as pd
import numpy as np
#import math
#import collections
import matplotlib.pyplot as plt
#from collections import defaultdict
#from sklearn.linear_model import LogisticRegression
#import os
#import re
#import itertools
#from mpl_toolkits.mplot3d import Axes3D
#import cv2
# %matplotlib inline
from matplotlib import gridspec
from collections import OrderedDict
import matplotlib.lines as mlines

# %%
linestyles_dict = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

# %% [markdown]
# # Optimal K

# %%
opt_min_latency_oe     = [847706,659310,470966,282622,94226,47166,9466]
opt_min_latency_oe.reverse() 
opt_min_latency_enum   = [21258720989,12859244741,6561398069,2362572837,262479149,65717669,2631069]
opt_min_latency_enum.reverse() 
opt_min_latency_merge  = [391388,304436,217508,130573,43607,21880,4471]
opt_min_latency_merge.reverse() 
opt_min_latency_bubble = [1304139,1014299,724539,434779,144939,47176,14539]
opt_min_latency_bubble.reverse() 
opt_min_latency_custom = [391294,304342,217414,130486,43534,21808,4414]
opt_min_latency_custom.reverse() 


opt_max_latency_oe     = [29761452996,18002354356,9185537076,3307349812,367386756,91962676,3675076]
opt_max_latency_oe.reverse() 
opt_max_latency_enum   = [38264967453,23146072517,11810110773,4252387621,472381293,118251173,4727773]
opt_max_latency_enum.reverse() 
opt_max_latency_merge  = [63806417548,39486696036,20789895508,7376785498,797209522,199849180,8294221]
opt_max_latency_merge.reverse() 
opt_max_latency_bubble = [1304139,1014299,724539,434779,144939,47176,14539]
opt_max_latency_bubble.reverse() 
opt_max_latency_custom = [391294,304342,217414,130486,43534,21808,4414]
opt_max_latency_custom.reverse()

# %% [markdown]
# # default

# %%
def_min_latency_oe = [847717,659321,470977,282633,94237,47177,9477]
def_min_latency_oe.reverse()
def_min_latency_enum = [21258721000,12859244752,6561398080,2362572848,262479160,65717680,2631080]
def_min_latency_enum.reverse()
def_min_latency_merge = [391399,304447,217519,130584,43618,21891,4477]
def_min_latency_merge.reverse()
def_min_latency_bubble = [2673408,2079236,1485228,891220,297048,148628,29728]
def_min_latency_bubble.reverse()
def_min_latency_custom = [586909,456481,326089,195697,65269,32689,6589]
def_min_latency_custom.reverse()



def_max_latency_oe  = [29761453007,18002354367,9185537087,3307349823,367386767,91962687,3675087]
def_max_latency_oe.reverse()
def_max_latency_enum = [38264967464,23146072528,11810110784,4252387632,472381304,118251184,4727784]
def_max_latency_enum.reverse()
def_max_latency_merge = [63806417559,39486696047,20789895519,7376785509,797209533,199849191,8294227]
def_max_latency_merge.reverse()
def_max_latency_bubble = [2673408,2079236,1485228,891220,297048,148628,29728]
def_max_latency_bubble.reverse()
def_max_latency_custom = [586909,456481,326089,195697,65269,32689,6589]
def_max_latency_custom.reverse()

# %% [markdown]
# # plot

# %%
data_set_size      = ["723","3623","7243","21735","36223","50711","65203"]
linewidth = 1.8

legend_elements = [mlines.Line2D([], [], linestyle=linestyles_dict["dashed"], color='black',\
                                 label='Odd-Even',linewidth = linewidth),\
                   
                   mlines.Line2D([], [], linestyle= linestyles_dict['dotted'],color='green', \
                                 label="Enumeration",linewidth = linewidth),\
                   
                   mlines.Line2D([], [], linestyle=linestyles_dict["solid"],color='red',\
                                 label='Merge',linewidth = linewidth),\
                   
                    mlines.Line2D([], [], linestyle=linestyles_dict['dashdotted'],color='darkorange',\
                                 label='Bubble',linewidth = linewidth),\
                  
                    mlines.Line2D([], [], linestyle=linestyles_dict['densely dashdotdotted'],color='blue',\
                                 label='Custom',linewidth = linewidth)]

# %%
fig,axs   = plt.subplots(nrows=2, ncols=1,figsize=(8,6.6),dpi=1000)
k = 97
fontsize= 12.5

props = dict(boxstyle='round', facecolor='white', alpha=0.5)

axs[0].plot(data_set_size,def_min_latency_oe, color= "black", linestyle = linestyles_dict["dashed"],linewidth=linewidth)
axs[0].plot(data_set_size,def_min_latency_merge, color = "red", linestyle = linestyles_dict["solid"],linewidth=linewidth)
axs[0].plot(data_set_size,def_min_latency_enum, color = "green", linestyle = linestyles_dict['dotted'],linewidth=linewidth)
axs[0].plot(data_set_size,def_min_latency_bubble, color = "darkorange", linestyle = linestyles_dict['dashdotted'],linewidth=linewidth)
axs[0].plot(data_set_size,def_min_latency_custom, color = "blue", linestyle = linestyles_dict['densely dashdotdotted'],linewidth=linewidth)
axs[0].set_xticks(range(len(data_set_size)))
axs[0].set_xticklabels(data_set_size,fontsize=fontsize)
axs[0].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[0].margins(x=0)
axs[0].set_ylabel("Minimum Latency", fontsize=fontsize)
axs[0].set_yticks(np.arange(0,99, step=14))
axs[0].text(.02,.95, r'K = 5',fontsize=fontsize1,transform=axs[0].transAxes,verticalalignment='top', bbox=props)
axs[0].set_ylim(pow(10,3))
axs[0].set_yscale("symlog")

k = k +1


axs[1].plot(data_set_size, def_max_latency_oe, color= "black", linestyle = linestyles_dict["dashed"],linewidth=linewidth)
axs[1].plot(data_set_size,def_max_latency_merge, color = "red", linestyle = linestyles_dict["solid"],linewidth=linewidth)
axs[1].plot(data_set_size,def_max_latency_enum, color = "green", linestyle = linestyles_dict['dotted'],linewidth=linewidth)
axs[1].plot(data_set_size,def_max_latency_bubble, color = "darkorange", linestyle = linestyles_dict['dashdotted'],linewidth=linewidth)
axs[1].plot(data_set_size,def_max_latency_custom, color = "blue", linestyle = linestyles_dict['densely dashdotdotted'],linewidth=linewidth)
axs[1].set_xticks(range(len(data_set_size)))
axs[1].set_xticklabels(data_set_size,fontsize=fontsize)
axs[1].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[1].margins(x=0)
axs[1].set_ylabel("Maximum Latency", fontsize=fontsize)
axs[1].set_yticks(np.arange(0,99, step=14))
axs[1].text(.02,.95, r'K = 5',fontsize=fontsize1,transform=axs[1].transAxes,verticalalignment='top', bbox=props)
axs[1].set_ylim(pow(10,3))
axs[1].set_yscale("symlog")



plt.subplots_adjust(wspace = 0.27,hspace=0.38)
plt.legend(handles=legend_elements,fontsize = fontsize,ncol=3,handletextpad=0.5,bbox_to_anchor=(.9,2.7),frameon = False)
plt.savefig('def_min_Max_latency.pdf', bbox_inches='tight')

# %%
from math import log
a=[log(x) for x in opt_min_latency_merge]
print(a)

b = [log(x) for  x in opt_min_latency_custom ]
print (b)
# Out:
# [8.405367376233981, 9.993328256535918, 10.682972966908995, 11.779687736319495, 12.289990910443644, 12.626216163417073, 12.877454674301909]
# [8.392536586816682, 9.990032153936314, 10.681297520974782, 11.77902122029652, 12.289558649019924, 12.625907348050069, 12.877214474577238]

# %%
fig,axs   = plt.subplots(nrows=2, ncols=1,figsize=(8,6.6),dpi=1000)
# fig,axs   = plt.subplots(nrows=2, ncols=1,figsize=(8,12),dpi=1000)
k = 97
fontsize= 12.5
fontsize1 = fontsize

props = dict(boxstyle='round', facecolor='white', alpha=0.5)

axs[0].plot(data_set_size,opt_min_latency_oe, color= "black", linestyle = linestyles_dict["dashed"],linewidth=linewidth)
axs[0].plot(data_set_size,opt_min_latency_merge, color = "red", linestyle = linestyles_dict["solid"],linewidth=linewidth)
axs[0].plot(data_set_size,opt_min_latency_enum, color = "green", linestyle = linestyles_dict['dotted'],linewidth=linewidth)
axs[0].plot(data_set_size,opt_min_latency_bubble, color = "darkorange", linestyle = linestyles_dict['dashdotted'],linewidth=linewidth)
axs[0].plot(data_set_size,opt_min_latency_custom, color = "blue", linestyle = linestyles_dict['densely dashdotdotted'],linewidth=linewidth)
axs[0].set_xticks(range(len(data_set_size)))
axs[0].set_xticklabels(data_set_size,fontsize=fontsize)
axs[0].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[0].set_ylabel("Minimum Latency", fontsize=fontsize)
axs[0].xaxis.grid(True)
# axs[0].yaxis.grid(True)
# axs[0].margins(x=0)
axs[0].set_ylim(pow(10,3))
axs[0].set_yscale("log")
axs[0].text(-0.09, pow(10,5), r'K=2', fontsize=fontsize1)
axs[0].text(0.8, pow(10,6), r'K=1', fontsize=fontsize1)
axs[0].text(1.9, pow(10,6), r'K=2', fontsize=fontsize1)
axs[0].text(2.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[0].text(3.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[0].text(4.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[0].text(5.8, pow(10,7), r'K=2', fontsize=fontsize1)
k = k + 1



axs[1].plot(data_set_size,opt_max_latency_oe, color= "black", linestyle = linestyles_dict["dashed"],linewidth=linewidth)
axs[1].plot(data_set_size,opt_max_latency_merge, color = "red", linestyle = linestyles_dict["solid"],linewidth=linewidth)
axs[1].plot(data_set_size,opt_max_latency_enum, color = "green", linestyle = linestyles_dict['dotted'],linewidth=linewidth)
axs[1].plot(data_set_size,opt_max_latency_bubble, color = "darkorange", linestyle = linestyles_dict['dashdotted'],linewidth=linewidth)
axs[1].plot(data_set_size,opt_max_latency_custom, color = "blue", linestyle = linestyles_dict['densely dashdotdotted'],linewidth=linewidth)
axs[1].set_xticks(range(len(data_set_size)))
axs[1].set_xticklabels(data_set_size,fontsize=fontsize)
axs[1].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[1].set_ylabel("Maximum Latency", fontsize=fontsize)
axs[1].xaxis.grid(True)
axs[1].set_yticks(np.arange(0,99, step=14))
axs[1].set_ylim(pow(10,3))
axs[1].text(-0.09, pow(10,5), r'K=2', fontsize=fontsize1)
axs[1].text(0.8, pow(10,6), r'K=1', fontsize=fontsize1)
axs[1].text(1.9, pow(10,6), r'K=2', fontsize=fontsize1)
axs[1].text(2.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[1].text(3.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[1].text(4.9, pow(10,7), r'K=2', fontsize=fontsize1)
axs[1].text(5.8, pow(10,7), r'K=2', fontsize=fontsize1)
axs[1].set_yscale("log")



plt.subplots_adjust(wspace = 0.27,hspace=0.38)
plt.legend(handles=legend_elements,fontsize = fontsize,ncol=3,handletextpad=0.5,bbox_to_anchor=(.9,2.7),frameon = False)
plt.savefig('opt_min_Max_latency.pdf', bbox_inches='tight')

# %% [markdown]
# # opt accuracy

# %%
opt_train_acc = [91.842,93.737,94.133,94.557,94.887,94.532,95.261]
opt_test_acc  = [91.654,93.842,94.512,94.111,95.566,95.422,95.513]
data_set_size      = ["723","3623","7243","21735","36223","50711","65203"]


def_train_acc = [90.049,93.433,93.815,93.876,94.36,94.171,95.149]
def_test_acc = [88.390,93.285,93.963,93.800,94.531,94.433,95.403]

# %%
legend_elements = [mlines.Line2D([], [], color='black',label='10 Fold Cross-Validation Accuracy'),\
                   mlines.Line2D([], [], color='grey', label="Test Accuracy"),\
                  ]

# %%
fig,axs   = plt.subplots(nrows=2, ncols=1,figsize=(8,6.6),dpi=1000)
k = 97
fontsize= 12.5
fontsize1 = fontsize
barWidth = 0.35 
x_pos1 = np.arange(len(data_set_size))
x_pos2 = [x + barWidth for x in x_pos1]

props = dict(boxstyle='round', facecolor='white', alpha=0.5)

axs[0].bar(x_pos1, def_train_acc, width=barWidth,alpha=0.7,color="black")
axs[0].bar(x_pos2, def_test_acc, width=barWidth,alpha=0.7,color="grey")
axs[0].set_xticks(range(len(data_set_size)))
axs[0].set_xticklabels(data_set_size,fontsize=fontsize)
axs[0].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[0].set_ylabel("Accuracy (%)", fontsize=fontsize)
axs[0].set_ylim(84,97)
axs[0].set_yticks(np.arange(84,98, step=2))
axs[0].yaxis.grid(True)
axs[0].text(.02,.95, r'K = 5',fontsize=fontsize1,transform=axs[0].transAxes,verticalalignment='top', bbox=props)
axs[0].margins(x=0)
k = k + 1


axs[1].bar(x_pos1, opt_train_acc, width=barWidth, alpha=0.7,color="black")
axs[1].bar(x_pos2, opt_test_acc, width=barWidth,alpha=0.7,color="grey")
axs[1].set_xticks(range(len(data_set_size)))
axs[1].set_xticklabels(data_set_size,fontsize=fontsize)
axs[1].set_xlabel("("+chr(k)+") Dataset Size", fontsize=fontsize)
axs[1].set_ylabel("Accuracy (%)", fontsize=fontsize)
axs[1].set_ylim(84,97)
axs[1].set_yticks(np.arange(84,98, step=2))
axs[1].yaxis.grid(True)
axs[1].margins(x=0)
axs[1].text(-0.09, 92, r'K=2', fontsize=fontsize1)
axs[1].text(1.2, 94, r'K=1', fontsize=fontsize1)
axs[1].text(1.9, 95, r'K=2', fontsize=fontsize1)
axs[1].text(2.9, 95, r'K=2', fontsize=fontsize1)
axs[1].text(3.9, 96, r'K=2', fontsize=fontsize1)
axs[1].text(4.9, 96, r'K=2', fontsize=fontsize1)
axs[1].text(5.8, 96, r'K=2', fontsize=fontsize1)


plt.subplots_adjust(wspace = 0.27,hspace=0.38)
plt.legend(handles=legend_elements,fontsize = fontsize,ncol=3,handletextpad=0.5,bbox_to_anchor=(.9,2.7),frameon = False)
plt.savefig('def_opt_acc.pdf', bbox_inches='tight')

# %% [markdown]
# # % change
